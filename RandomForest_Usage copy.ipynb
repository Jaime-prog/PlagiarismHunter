# %%
import joblib
import pandas as pd
import numpy as np
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Convierte los codigos en secuencias de enteros para que puedan ser procesados
def get_tokenizer(features):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(features['code_java_1'] + features['code_java_2'])
    return tokenizer

# %%
# Asegurarse de que todas las secuencias tengan la misma longitud
def get_max_length(features1, features2):
    max_f1 = max(len(seq) for seq in features1) 
    max_f2 = max(len(seq) for seq in features2)
    max_length = max(max_f1, max_f2)

    return max_length

# %%
# Preprocessing function
def preprocess_java_code(code):
    # Remove single-line comments
    code = re.sub(r'//.*', '', code)
    # Remove multi-line comments
    code = re.sub(r'/\*.*?\*/', '', code, flags=re.DOTALL)
    # Remove extra whitespace and line breaks
    code = re.sub(r'\s+', ' ', code).strip()
    return code

# %%
def predict_plagiarism(code1, code2, tokenizer, max_length, model):
    # Tokenización de los códigos
    sequence_code1 = tokenizer.texts_to_sequences([code1])
    sequence_code2 = tokenizer.texts_to_sequences([code2])

    # Padding de las secuencias
    # max_length = max(max(len(seq) for seq in sequence_code1), max(len(seq) for seq in sequence_code2))
    sequence_code1 = pad_sequences(sequence_code1, maxlen=max_length)
    sequence_code2 = pad_sequences(sequence_code2, maxlen=max_length)

    # Realizar la predicción
    # prediction = model.predict(np.concatenate([sequence_code1, sequence_code2], axis=1))
    # print(sequence_code1 + sequence_code2)
    prediction = model.predict(sequence_code1 + sequence_code2)
    
    # Devolver el resultado de la predicción
    return prediction[0]

# %%
# Load the saved model
model = joblib.load('random_forest_model.pkl')

# %%
path_code1 = "test.java"
path_code2 = "test copy.java"

# %%
with open(path_code1, 'r') as file:
    java_code1 = file.read()
print(java_code1)
# Out:
# public class Fibonacci {
#     public static void main(String[] args) {
#         int n = 10, t1 = 0, t2 = 1;
#         System.out.print("First " + n + " terms: ");
#         for (int i = 1; i <= n; ++i) {
#             System.out.print(t1 + " + ");
#             int sum = t1 + t2;
#             t1 = t2;
#             t2 = sum;
#         }
#     }
# }

# %%
with open(path_code2, 'r') as file:
    java_code2 = file.read()
print(java_code2)
# Out:
# public class Fibonacci {
#     public static void main(String[] args) {
#         int n = 10, t1 = 0, t2 = 1;
#         System.out.print("First " + n + " terms: ");
#         for (int i = 1; i <= n; ++i) {
#             System.out.print(t1 + " + ");
#             int sum = t1 + t2;
#             t1 = t2;
#             t_2 = sum;
#         }
#     }
# }

# %%
java_code1 = preprocess_java_code(java_code1)
java_code2 = preprocess_java_code(java_code2)

# %%
data = {'code_java_1': [java_code1], 'code_java_2': [java_code2]}
features = pd.DataFrame(data)
features.head()
# Out:
#                                          code_java_1  \
# 0  public class Fibonacci { public static void ma...
#
#                                          code_java_2
# 0  public class Fibonacci { public static void ma...

# %%
tokenizer = get_tokenizer(features)

# %%
features1 = features[['code_java_1']]
features2 = features[['code_java_2']]

# %%
max_length = get_max_length(features1, features2)

# %%
max_length
# Out:
# 11

# %%
predict_plagiarism(java_code1, java_code2, tokenizer, max_length, model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 predict_plagiarism(java_code1, java_code2, tokenizer, max_length, model)
#
# Cell In[17], line 14, in predict_plagiarism(code1, code2, tokenizer, max_length, model)
#       9 sequence_code2 = pad_sequences(sequence_code2, maxlen=max_length)
#      11 # Realizar la predicción
#      12 # prediction = model.predict(np.concatenate([sequence_code1, sequence_code2], axis=1))
#      13 # print(sequence_code1 + sequence_code2)
# ---> 14 prediction = model.predict(sequence_code1 + sequence_code2)
#      16 # Devolver el resultado de la predicción
#      17 return prediction[0]
#
# File c:\Users\Ricardo Caceres\.virtualenvs\NutryPlus-EF-keS824Fg\lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File c:\Users\Ricardo Caceres\.virtualenvs\NutryPlus-EF-keS824Fg\lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\Ricardo Caceres\.virtualenvs\NutryPlus-EF-keS824Fg\lib\site-packages\sklearn\ensemble\_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
#     648 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     649     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\Ricardo Caceres\.virtualenvs\NutryPlus-EF-keS824Fg\lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File c:\Users\Ricardo Caceres\.virtualenvs\NutryPlus-EF-keS824Fg\lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 11 features, but RandomForestClassifier is expecting 10398 features as input.

# %%
import pandas as pd

data = {'code_java_1': [java_code1], 'code_java_2': [java_code2]}
df = pd.DataFrame(data)
df.head()

# %%
features = df[['code_java_1', 'code_java_2']]
features_sequence_code1, features_sequence_code2 = tokenizar(features)

# %%
features_code1, features_code2 = padding(
    features_sequence_code1,
    features_sequence_code2
)

# %%
features_concatenated = np.concatenate(
    (
        features_code1,
        features_code2
    ), 
    axis = 1
)

# %%
# Make predictions
predictions = model.predict(features_concatenated)

# Print the predictions
print(predictions)
